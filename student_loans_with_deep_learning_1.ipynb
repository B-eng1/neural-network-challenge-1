# %% [markdown]
# <a href="https://colab.research.google.com/github/B-eng1/neural-network-challenge-1/blob/main/student_loans_with_deep_learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
import sklearn as skl
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: credit_ranking, Length: 1599, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
features = X = loans_df.drop(columns=["credit_ranking"])


# Review the features DataFrame
features
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
def create_model(hp):
    model = Sequential()
    model.add(Dense(64, input_dim=10, activation= "relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))
    model = tf.keras.models.Sequential("features")

# Review the number of features
features
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer = 64
hidden_nodes_layer2 = 32

# Review the number hidden nodes in the first layer
model = tf.keras.models.Sequential()
number_input_features = len(X_train.iloc[0])
hidden_nodes_layer1 =  (number_input_features + 1) // 2
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)


# Define the number of hidden nodes for the second hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Define the number of neurons in the output layer
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Create the Sequential model instance
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))
# Add the first hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1))

# Add the second hidden layer
model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 6)                   │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │              33 │
# ...

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
compile = model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5000 - loss: 0.6952
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6047 - loss: 0.6543
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6662 - loss: 0.6319
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7236 - loss: 0.5917
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7012 - loss: 0.5599
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7142 - loss: 0.5533
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7226 - loss: 0.5454
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7380 - loss: 0.5324
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7179 - loss: 0.5381
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7203 - loss: 0.5477
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7292 - loss: 0.5368
# Epoch 12/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
y_pred = model.predict(X_test_scaled)
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
model_loss, model_accuracy
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 13/13 - 1s - 53ms/step - accuracy: 0.7350 - loss: 0.5229
# (0.5228857398033142, 0.7350000143051147)

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
model_path = "student_loans.keras"

# Export your model to a keras file
model.save(model_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
model_path = "student_loans.keras"

# Load the model to a new object
model = tf.keras.models.load_model(model_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = model.predict(X_test_scaled)
# Display a sample of the predictions
print(predictions)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# [[0.4829267 ]
#  [0.23277678]
#  [0.8831383 ]
#  [0.63369995]
#  [0.9845461 ]
#  [0.7217698 ]
#  [0.88423526]
#  [0.0421328 ]
#  [0.61846364]
#  [0.36107868]
#  [0.83261967]
#  [0.32355535]
#  [0.43462324]
#  [0.91788805]
#  [0.5345733 ]
#  [0.33011374]
#  [0.87895846]
#  [0.32682782]
#  [0.57760406]
#  [0.35302156]
#  [0.47756845]
#  [0.8959945 ]
#  [0.27177623]
#  [0.940409  ]
#  [0.24165967]
#  [0.9147073 ]
#  [0.8804021 ]
#  [0.34629485]
#  [0.31875947]
#  [0.06886617]
#  [0.50100994]
#  [0.97242403]
#  [0.31875947]
#  [0.9447169 ]
#  [0.29539102]
#  [0.647025  ]
#  [0.23745261]
#  [0.4016173 ]
#  [0.96193725]
#  [0.31875947]
#  [0.8284879 ]
#  [0.06848644]
#  [0.2569892 ]
#  [0.8877077 ]
#  [0.1380188 ]
#  [0.675975  ]
#  [0.16323724]
#  [0.34788704]
#  [0.13393722]
#  [0.7848665 ]
#  [0.203269  ]
#  [0.3362053 ]
#  [0.90738046]
#  [0.1060877 ]
#  [0.318886  ]
#  [0.6963316 ]
#  [0.82424366]
#  [0.8655    ]
#  [0.79157835]
# ...

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(predictions, columns=["predictions"]).round(0)

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       188
#            1       0.79      0.68      0.73       212
#
#     accuracy                           0.73       400
#    macro avg       0.74      0.74      0.73       400
# weighted avg       0.74      0.73      0.73       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# 1.)
# The necesarry data that would need to be collected would be based on the Student's income level/Credit score,( if low income, it may cause a loan company to put a somewhat low apr% raiting at first and possibly recommend them to seek financial assitance from government entities.)
#  Another factor may be based on their
# combined family income/ credit score. If their family has an average to high income a credit company will have more favor towards that in expectation of payments.
#  Next would be the type of School/ Institution the student is entering, such as undergraduate would more than likely be accepted as there are more options for loans at most loaning companies.
#  Some issues for denials would be based on student loan history(if applicable), credit score, background checks of payment history for bills or loans. While being somewhat intrusive all this data is necesarry for loan companies.
#  2.)
#  Based upon gathering this data I would use context-based filtering due to the differences in data selection as this may become an unbalanced data model.
#  3.)
#  One real world situation could be a student who has just graduated from high school (with honor grades and some college credits) applying for a loan to a university but has little to no income. However, their parents have no credit score, a well paying stable income, and are willing to sign on the students behalf. Based on this information a loan company might set a higher payment recommendation for the student to receive the loan.
#  The next situation is an adult who has some college credits(above grade point average), is working full-time, has a good credit score (700), and has a great history of paying bills on time is requesting a loan to pay for the remaining balance of a graduate program at a private university. More than likely based on this data a loan company will take the risk of giving the student the loan.
#
#   These two situations are similar but vastly different and a biased decision could be taken upon from a loan company due to credit score alone.

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
